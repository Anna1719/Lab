# %% [markdown]
# Лабораторная работа.
# База данных https://archive.ics.uci.edu/ml/datasets/banknote+authentication#
# База данных включает в себя параметры аутентификации банкнот и класс, задаваемый значениями 0 и 1 - т.е. является объект на картинке банкнотой или нет
# Задачей является определение класса картинки (банкнота или нет)
# Чтение, описание и обработка данных:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('../Documents/Studies/banknote/banknote.data', header = None, sep = ',', engine = 'python')

# %%
data
# Out:
#              0         1          2         3  4
# 0     3.621600   8.66610  -2.807300 -0.446990  0
# 1     4.545900   8.16740  -2.458600 -1.462100  0
# 2     3.866000  -2.63830   1.924200  0.106450  0
# 3     3.456600   9.52280  -4.011200 -3.594400  0
# 4     0.329240  -4.45520   4.571800 -0.988800  0
# 5     4.368400   9.67180  -3.960600 -3.162500  0
# 6     3.591200   3.01290   0.728880  0.564210  0
# 7     2.092200  -6.81000   8.463600 -0.602160  0
# 8     3.203200   5.75880  -0.753450 -0.612510  0
# 9     1.535600   9.17720  -2.271800 -0.735350  0
# 10    1.224700   8.77790  -2.213500 -0.806470  0
# 11    3.989900  -2.70660   2.394600  0.862910  0
# 12    1.899300   7.66250   0.153940 -3.110800  0
# 13   -1.576800  10.84300   2.546200 -2.936200  0
# 14    3.404000   8.72610  -2.991500 -0.572420  0
# 15    4.676500  -3.38950   3.489600  1.477100  0
# 16    2.671900   3.06460   0.371580  0.586190  0
# 17    0.803550   2.84730   4.343900  0.601700  0
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1372, step=1)

# %%
data.columns = [u'variance', u'skewness', u'curtosis', u'entropy',
                u'class']

# %% [markdown]
# Attribute Information:
#
# 1. variance of Wavelet Transformed image (continuous)
# 2. skewness of Wavelet Transformed image (continuous)
# 3. curtosis of Wavelet Transformed image (continuous)
# 4. entropy of image (continuous)
# 5. class (integer)

# %%
data.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
data.tail()
# Out:
#       variance  skewness  curtosis  entropy  class
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1

# %%
print(data.shape)
print(data.columns)
# Out:
# (1372, 5)
# Index(['variance', 'skewness', 'curtosis', 'entropy', 'class'], dtype='object')

# %%
data.describe(include = 'all')
# Out:
#           variance     skewness     curtosis      entropy        class
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# []
# ['variance', 'skewness', 'curtosis', 'entropy', 'class']

# %%
X = data.drop(('class'), axis = 1)
y = data['class']
y.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# Так как пропусков нет, то очистку от них не проводим.Также нет смысла делать векторизацию, т.к. в данных только количественные и бинарные признаки. Но нужно делать нормализацию количественных признаков:

# %%
X = (X - X.mean(axis = 0))/X.std(axis = 0)

# %%
X.head()
# Out:
#    variance  skewness  curtosis   entropy
# 0  1.121397  1.149036 -0.975614  0.354432
# 1  1.446538  1.064065 -0.894710 -0.128721
# 2  1.207369 -0.777069  0.122174  0.617848
# 3  1.063355  1.295005 -1.254940 -1.143612
# 4 -0.036758 -1.086642  0.736462  0.096552

# %%
print(X.shape)
print(y.shape)
# Out:
# (1372, 4)
# (1372,)

# %% [markdown]
# Объединяем:

# %%
dataF = pd.concat((X, y), axis = 1)
dataF.corr()
# Out:
#           variance  skewness  curtosis   entropy     class
# variance  1.000000  0.264026 -0.380850  0.276817 -0.724843
# skewness  0.264026  1.000000 -0.786895 -0.526321 -0.444688
# curtosis -0.380850 -0.786895  1.000000  0.318841  0.155883
# entropy   0.276817 -0.526321  0.318841  1.000000 -0.023424
# class    -0.724843 -0.444688  0.155883 -0.023424  1.000000

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(dataF, alpha = .05, figsize = (10, 10))
pass
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.

# %% [markdown]
# Рассмотрим график зависимости двух признаков (skewness и entropy)

# %%
plt.plot(data['skewness'], data['entropy'], 'o', alpha = 0.01);

# %%
plt.figure(figsize = (10, 6))

plt.scatter(dataF[dataF['class'] == 0]['skewness'],
            dataF[dataF['class'] == 0]['entropy'],
            alpha = 0.15,
            label = 'not a banknote',
            color = 'g')

plt.scatter(dataF[dataF['class'] == 1]['skewness'],
            dataF[dataF['class'] == 1]['entropy'],
            alpha = 0.25,
            label = 'banknote',
            color = 'b')

plt.xlabel('skewness')
plt.ylabel('entropy')
plt.legend()
plt.grid()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 1097 275

# %% [markdown]
# k-nearest neighbors algorithm
# Построим классификатор для количества "соседей", к примеру, = 20

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 20)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=20, p=2,
#            weights='uniform')

# %% [markdown]
# Для оценки качества классификатора посчитаем значения ошибок на тренировочной и тестовой выборке:

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.00729261622607 0.0109090909091

# %% [markdown]
# Построим матрицу ошибок для созданного классификатора:

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[154   3]
#  [  0 118]]

# %% [markdown]
# Для более точного обучения подберем оптимальное количество "соседей".
# Выясняем, что наилучшее значение параметра 'n_neighbors' и ошибка на тренировочной выборки равны:

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 2,3, 5, 10, 15, 20, 25]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.000911577028259 10

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.000911577028259 0.0

# %% [markdown]
# Нейронная сеть

# %%
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# Обучаем классификатор:

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %% [markdown]
# Классифицируем объект №125 из тестовой выборки (как пример)

# %%
n=125
pic = X_test[n:n+1]
clas = y_test[n:n+1]
print(mlp_model.predict(pic))
# Out:
# [1]

# %%
clas
# Out:
# 989    1
# Name: class, dtype: int64

# %% [markdown]
# На данном объекте (как и на проверенных мной 7 других) работает верно
#
# Проверяем качество классификатора:

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %% [markdown]
# Посчитаем ошибки на обучающей и тестовой выборках:

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.0 0.0

# %% [markdown]
# Гиперпараметры
# Поиск оптимального значения параметра регуляризации alpha

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (100,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 10)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(alpha_arr, train_err, 'b-o', label = 'test')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'train')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.0

# %% [markdown]
# Оптимальное значение alpha:

# %%
alpha_opt = min(alpha_arr[test_err == min_test_err])
print(alpha_opt)
# Out:
# 0.001

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (100,),
                          solver = 'lbfgs', activation = 'logistic', random_state = 10)
mlp_model.fit(X_train, y_train)

print(np.min(train_err), np.min(test_err))
# Out:
# 0.0 0.0

# %% [markdown]
# Подбор оптимального количества нейронов на скрытом слое

# %%
hidden_layer_sizes_arr = np.arange(50,300,50)
test_err_hidden_layer = []
train_err_hidden_layer = []
for hidden_layer_sizes in hidden_layer_sizes_arr:
    mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = hidden_layer_sizes, 
                              solver = 'lbfgs', activation = 'logistic', random_state = 10)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err_hidden_layer.append(np.mean(y_train != y_train_pred))
    test_err_hidden_layer.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(hidden_layer_sizes_arr, train_err_hidden_layer, 'b-o', label = 'test')
plt.semilogx(hidden_layer_sizes_arr, test_err_hidden_layer, 'r-o', label = 'train')
plt.xlim([np.max(hidden_layer_sizes_arr), np.min(hidden_layer_sizes_arr)])
plt.title('Error vs. hidden_layer_sizes')
plt.xlabel('hidden_layer_sizes')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Ошибка при оптимальном количестве нейронов:

# %%
print(np.min(train_err_hidden_layer), np.min(test_err_hidden_layer))
hidden_layer = hidden_layer_sizes_arr[test_err_hidden_layer == np.min(test_err_hidden_layer)]
print(hidden_layer)
# Out:
# 0.0 0.0
# [100 150 200 250]
